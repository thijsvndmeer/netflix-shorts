# %%
import pandas as pd
import h5py
import numpy as np
import netflix_recommender as nr

# %%
#example session_data
data = {
    'videos': ['--Jiv5iYqT8', '-JhNO_E3aEE', '0AspXDFcGlw', '29YDqiuyaOU', 'Gh9kc9DiDnE'],
    'liked': [1, 0, 0, 0, 0],
    'watched': [0.8, 0.02, 0.05, 0.9, 1.9]
}
user_data = pd.DataFrame(data)

print(user_data)
# Out:
#         videos  liked  watched
# 0  --Jiv5iYqT8      1     0.80
# 1  -JhNO_E3aEE      0     0.02
# 2  0AspXDFcGlw      0     0.05
# 3  29YDqiuyaOU      0     0.90
# 4  Gh9kc9DiDnE      0     1.90

# %%
class recommender():
    def __init__(self, data_file, n: int = 5, k: int = 3, like_strenght: bool = 1.4, threshold: bool = 1.3):
        self.n = n
        self.k = k
        self.like = like_strenght
        self.feature_file = data_file
        self.threshold = threshold
        print(f'recommender enabled with video embeddings from {self.feature_file}')

    def change_file(self, data_file):
        self.feature_file = data_file
        print(f'changed datafile to {self.feature_file}')

######################################################################################################################################################################################################################################################################################################################################################################################   
    
    def recommend(self, user_data):
        #step 1: Construct sim_matrix based on user data
        sim_matrix = pd.DataFrame(columns=user_data['videos'])
        
        
        #loop over each column and calculate the similarity score. 
        for column in sim_matrix:
            content = []
            index = []
            
            with h5py.File(self.feature_file, 'r') as f:
                feature_one = f[column][:]
                

                #calculate the cosine_sim between each video in the dataset  (include a random factor to maybe reduce compute if necessary)
                for video, obj in f.items():
                    #skips to the next video if it is in the user data, thereby insuring that a video is never recommende twice (can maybe be changed later idk)
                    if video in user_data['videos'].values:
                        continue
                    feature_two = obj[:]
                    cos_sim = np.dot(feature_one, feature_two) / (np.linalg.norm(feature_one) * np.linalg.norm(feature_two))
                    content.append(cos_sim)
                    index.append(video)
                    
                
            sim_matrix[column] = content
            sim_matrix.index = index
            
        #step 2: find the k nearest neighbours for each video and vote
        recommend = pd.Series()
        
        for video, data in sim_matrix.iterrows():
            k_nearest = data.nlargest(self.k)
            video_value = sum([user_data.loc[user_data['videos'] == video, 'watched'].item() * (1 + ((self.like - 1)* user_data.loc[user_data['videos'] == video, 'liked'].item())) * k_nearest[video] for video in k_nearest.index]) / k_nearest.sum()

            if video_value > self.threshold: recommend[video] = video_value
        print(recommend)
            
            
        


        #step 3: randomly select n recommendations
    



        

######################################################################################################################################################################################################################################################################################################################################################################################


rec = recommender('test.h5')
rec.recommend(user_data)
# Out:
# recommender enabled with video embeddings from test.h5
# -yyoLJuNIJU    1.305524
# 1j8l24hHhgA    1.303074
# 1y20NC1_MGQ    1.303463
# 1yi8Mc-5kLc    1.306348
# 6DI_C-xXcOQ    1.309036
# 7Dxxk1az9Uo    1.313983
# 7s3dzArIVok    1.306143
# 9Okpnw0Ktt8    1.304405
# 9_T2VQgL2XY    1.312258
# 9smHLhj75CU    1.305995
# DNt7PNTuePY    1.312668
# DcfEOMgI_5o    1.308140
# GKuQDM9OlAQ    1.313380
# GtSNSaW9IRI    1.310805
# KJtmyW2urUk    1.315642
# LbkjkJzREd4    1.306244
# MbbKc8GJtFA    1.305741
# MoOwbXap6LM    1.308223
# PJlmYh27MHg    1.304833
# PsqrgV2RCCM    1.310780
# RIN6AtTxFgE    1.319356
# SLL5ziDWc6k    1.310142
# T8oTlWwAPFI    1.305012
# TKpXTy-sCxg    1.309414
# VY4Bo_Mcws4    1.305456
# WtnTZSJndPc    1.305113
# YER_g7jph94    1.309378
# YjfLp0bll5U    1.312380
# YsMdkGG2b0k    1.309959
# ZlFSjq7eU4Y    1.303939
# _yy4qamWAmk    1.317875
# avXk2EamFs4    1.308571
# b2dewDwIQyM    1.302667
# bZhBhpm6m_A    1.312831
# bwzuMk8SRzY    1.313695
# c35RsjYzAhY    1.310448
# cKw1b2-4aeU    1.302965
# fRCKKlTNxt8    1.301629
# jJ4zpJxcw4o    1.308367
# nfV87TgYH78    1.306177
# nkVUb4kdhig    1.319155
# ntsuIs20RW0    1.307479
# qaBlaPsuHQw    1.303117
# rKh4muRk_s0    1.313386
# rOoBvxdO0Ac    1.307267
# v8pFeR0jO38    1.310494
# yooamJf-T_8    1.307318
# ysLBlalu91s    1.308424
# dtype: float64

# %%
rec = nr.recommender('test.h5')

rec.recommend(nr.user_example())
# Out:
# recommender enabled with video embeddings from test.h5
# videos  --Jiv5iYqT8  -JhNO_E3aEE  0AspXDFcGlw  29YDqiuyaOU  Gh9kc9DiDnE
# 0          0.636217     0.654247     0.811549     0.565763     0.557355
# 1          0.902773     0.821598     0.704314     0.787231     0.791700
# 2          0.887511     0.884305     0.648926     0.859634     0.935279
# 3          0.887864     0.885948     0.725505     0.843884     0.880622
# 4          0.784328     0.790975     0.799862     0.716096     0.775239
# ..              ...          ...          ...          ...          ...
# 859        0.691897     0.723489     0.587993     0.740664     0.747190
# 860        0.762825     0.802943     0.693921     0.731527     0.735622
# 861        0.883055     0.843618     0.732242     0.777612     0.817304
# 862        0.874552     0.918199     0.726651     0.856444     0.869909
# 863        0.710698     0.760602     0.661009     0.757401     0.757801
#
# [864 rows x 5 columns]

# %%
def print_structure(name, obj):
    """Callback function to print the layout of the file"""
    if isinstance(obj, h5py.Dataset):
        print(f"Dataset: {name} (Shape: {obj.shape}, Type: {obj.dtype})")
    elif isinstance(obj, h5py.Group):
        print(f"Group: {name}")

# Open the file
with h5py.File('test.h5', 'r') as f:
    # This walks through the entire file hierarchy
    f.visititems(print_structure)
