# %%
import pandas as pd
import h5py
import numpy as np

# %%
def restructure_features(input_file, output_file):
    #step 1
    with h5py.File(input_file, 'r') as f:
        with h5py.File(output_file, 'w') as new_file:
            for name, obj in f.items():
                new_group = new_file.create_group(name)
                for n2, o2 in obj.items():
                    if n2 != 'text_features':
                        new_file.copy(o2, new_group, name=n2)
    
    #step 2
    with h5py.File(output_file, 'r+') as f:
        current_vid = None
        datasets = []
        groups = []
        start = True
        video = None
        p = False
        weight = 0
        
    
        for name, obj in f.items():
            #check if the object is a group or a dataset (usefull for repeat sweeps)
            if isinstance(obj, h5py.Dataset):
                continue
    
            #step 1: get the name of the group, and thus, the video
            video = name.split('_')[1:-1]
            
            if len(video) > 1:
                video = ['_'.join(video)]
            video = video[0]
            
            
            #step 1.1: if this group is a new video, aggregate the datasets and remove the useless groups
            #step 1.2: Set the current video as the new current vid
            if video != current_vid: 
                if start == False:
                    average_vector = np.mean([np.array(vec) for vec in datasets], axis=0)
                    weight = len(datasets)
                    
                    if current_vid not in f: 
                        dataset = f.create_dataset(current_vid, data=average_vector)
                        dataset.attrs['weight'] = weight
                    
                    else:
                        dataset = f[current_vid]
                        weights = [dataset.attrs.get('weight'), weight]
                        new_average = np.average(np.array([dataset[:], average_vector]), axis=0, weights=weights)
                        dataset[...] = new_average
                        dataset.attrs['weight'] = sum(weights)
    
                    
                        
                    #deleting redundant groups containing the old data (which is now a duplicate)
                    for group in groups:
                        del f[group]
                    
                    datasets = []
                    groups = []
                else: start = False
                current_vid = video
                
              
                
            
            #step 2: add the data and group to the variable
            for title, value in obj.items():
                datasets.append(value[:])
            groups.append(name)
    
    
        average_vector = np.mean([np.array(vec) for vec in datasets], axis=0)
        weight = len(datasets)
        
        if current_vid not in f: 
            dataset = f.create_dataset(current_vid, data=average_vector)
            dataset.attrs['weight'] = weight
        
        else:
            dataset = f[current_vid]
            weights = [dataset.attrs.get('weight'), weight]
            new_average = np.average(np.array([dataset[:], average_vector]), axis=0, weights=weights)
            dataset[...] = new_average
            dataset.attrs['weight'] = sum(weights)
    
        for group in groups:
                del f[group]

# %%
import netflix_recommender as nr

nr.restructure_features('../../datacsv/features.h5', '../../datacsv/shortend_features.h5')

# %%
def print_structure(name, obj):
    """Callback function to print the layout of the file"""
    if isinstance(obj, h5py.Dataset):
        print(f"Dataset: {name} (Shape: {obj.shape}, Type: {obj.dtype})")
    elif isinstance(obj, h5py.Group):
        print(f"Group: {name}")

# Open the file
with h5py.File('../../datacsv/shortend_features.h5', 'r') as f:
    # This walks through the entire file hierarchy
    f.visititems(print_structure)
# Out:
# Dataset: --Jiv5iYqT8 (Shape: (768,), Type: float32)
# Dataset: -DXU2ZHuiTs (Shape: (768,), Type: float32)
# Dataset: -JhNO_E3aEE (Shape: (768,), Type: float32)
# Dataset: -N2mhlvygq0 (Shape: (768,), Type: float32)
# Dataset: -PzL4MTu3to (Shape: (768,), Type: float32)
# Dataset: -ZTTZtzzbmI (Shape: (768,), Type: float32)
# Dataset: -ZlL0LLfjKY (Shape: (768,), Type: float32)
# Dataset: -dMBMU9FCQU (Shape: (768,), Type: float32)
# Dataset: -dkz4Sk6UuA (Shape: (768,), Type: float32)
# Dataset: -qSADHn4nqw (Shape: (768,), Type: float32)
# Dataset: -r_jjQ_idz8 (Shape: (768,), Type: float32)
# Dataset: -yyoLJuNIJU (Shape: (768,), Type: float32)
# Dataset: 0AspXDFcGlw (Shape: (768,), Type: float32)
# Dataset: 0DFBoLZC3Bw (Shape: (768,), Type: float32)
# Dataset: 0IyuK069I-w (Shape: (768,), Type: float32)
# Dataset: 0OqXqd_s0ho (Shape: (768,), Type: float32)
# Dataset: 0X0-NpZpx6U (Shape: (768,), Type: float32)
# Dataset: 0XOzPjsD_ec (Shape: (768,), Type: float32)
# Dataset: 0_avQPM3L90 (Shape: (768,), Type: float32)
# Dataset: 0fwudBWsw9Q (Shape: (768,), Type: float32)
# Dataset: 0jSVwZ8w3C4 (Shape: (768,), Type: float32)
# Dataset: 0lNb6NAV6jg (Shape: (768,), Type: float32)
# Dataset: 0qWMjgpIECA (Shape: (768,), Type: float32)
# Dataset: 0quxzV2i_gQ (Shape: (768,), Type: float32)
# Dataset: 0u5O2--9www (Shape: (768,), Type: float32)
# Dataset: 0x6usdVsGbI (Shape: (768,), Type: float32)
# Dataset: 0xjYQiEDbj4 (Shape: (768,), Type: float32)
# Dataset: 1G5jMgx8GVU (Shape: (768,), Type: float32)
# Dataset: 1NfrTfIPl9Q (Shape: (768,), Type: float32)
# Dataset: 1Oq6vztcjgg (Shape: (768,), Type: float32)
# Dataset: 1UqGimF2hkI (Shape: (768,), Type: float32)
# Dataset: 1VZzulIl0DI (Shape: (768,), Type: float32)
# Dataset: 1WwlHv69kik (Shape: (768,), Type: float32)
# Dataset: 1bBOUr7rAHw (Shape: (768,), Type: float32)
# Dataset: 1fVPS7eLbME (Shape: (768,), Type: float32)
# Dataset: 1j8l24hHhgA (Shape: (768,), Type: float32)
# Dataset: 1l7e9BD_gos (Shape: (768,), Type: float32)
# Dataset: 1mxednlcHSs (Shape: (768,), Type: float32)
# Dataset: 1nwaifplKCI (Shape: (768,), Type: float32)
# Dataset: 1wc_mZ86ypg (Shape: (768,), Type: float32)
# Dataset: 1y20NC1_MGQ (Shape: (768,), Type: float32)
# Dataset: 1yi8Mc-5kLc (Shape: (768,), Type: float32)
# Dataset: 20gzgK-Z5Yw (Shape: (768,), Type: float32)
# Dataset: 23uAYGDpS_I (Shape: (768,), Type: float32)
# Dataset: 29YDqiuyaOU (Shape: (768,), Type: float32)
# Dataset: 2DdCmT_j5nE (Shape: (768,), Type: float32)
# Dataset: 2HwVVwlGHU0 (Shape: (768,), Type: float32)
# Dataset: 2WZCKiDOQ9Q (Shape: (768,), Type: float32)
# Dataset: 2aqgKA3uUwM (Shape: (768,), Type: float32)
# Dataset: 2gaEkPaykJo (Shape: (768,), Type: float32)
# Dataset: 2kt3CmzYGu4 (Shape: (768,), Type: float32)
# Dataset: 2mbvrOmirQg (Shape: (768,), Type: float32)
# Dataset: 2nChsqAPyHw (Shape: (768,), Type: float32)
# Dataset: 2nFh-kxiEng (Shape: (768,), Type: float32)
# Dataset: 2qyJ5r7Wink (Shape: (768,), Type: float32)
# Dataset: 2uSOBDMv_S0 (Shape: (768,), Type: float32)
# Dataset: 303wyvo5Uow (Shape: (768,), Type: float32)
# Dataset: 32iCWzpDpKs (Shape: (768,), Type: float32)
# Dataset: 381Di8Cw0-I (Shape: (768,), Type: float32)
# Dataset: 3F8oJh3J1T0 (Shape: (768,), Type: float32)
# Dataset: 3KdgZgQRDU0 (Shape: (768,), Type: float32)
# Dataset: 3UbNdsZot98 (Shape: (768,), Type: float32)
# Dataset: 3XD34HIx-00 (Shape: (768,), Type: float32)
# Dataset: 3bdQlGt3cEA (Shape: (768,), Type: float32)
# Dataset: 3fjlQw23hd0 (Shape: (768,), Type: float32)
# Dataset: 3iZ1TVOskhA (Shape: (768,), Type: float32)
# Dataset: 3iZIOZrzbYo (Shape: (768,), Type: float32)
# Dataset: 3jYu-qta0mU (Shape: (768,), Type: float32)
# Dataset: 3mN85wFz_Vk (Shape: (768,), Type: float32)
# Dataset: 3oqt6V9aJIM (Shape: (768,), Type: float32)
# Dataset: 3wqXNKYn-fQ (Shape: (768,), Type: float32)
# Dataset: 46-oS8F8_c8 (Shape: (768,), Type: float32)
# Dataset: 4EYZfAO5ZWs (Shape: (768,), Type: float32)
# Dataset: 4NcH64kh_24 (Shape: (768,), Type: float32)
# Dataset: 4PcxtcrI9_U (Shape: (768,), Type: float32)
# Dataset: 4WNq9Yy9m_g (Shape: (768,), Type: float32)
# Dataset: 4Xvu9fzPGhA (Shape: (768,), Type: float32)
# Dataset: 4c_4MGTCgHY (Shape: (768,), Type: float32)
# Dataset: 4ekcTVeV-1w (Shape: (768,), Type: float32)
# Dataset: 4fwQKF64AWY (Shape: (768,), Type: float32)
# Dataset: 4mdd9P7Tn6I (Shape: (768,), Type: float32)
# Dataset: 4t2pP2KLlgU (Shape: (768,), Type: float32)
# Dataset: 4x8o78xHel8 (Shape: (768,), Type: float32)
# Dataset: 5Ii0_2kAYlU (Shape: (768,), Type: float32)
# Dataset: 5LX01_nSeZU (Shape: (768,), Type: float32)
# Dataset: 5SRxYONb12I (Shape: (768,), Type: float32)
# Dataset: 5XnGKA75dtI (Shape: (768,), Type: float32)
# Dataset: 5ZHYDynRjV4 (Shape: (768,), Type: float32)
# Dataset: 5aY5jTL60pA (Shape: (768,), Type: float32)
# Dataset: 5eSrShL8dt8 (Shape: (768,), Type: float32)
# Dataset: 5fLlgS6aO9k (Shape: (768,), Type: float32)
# Dataset: 5lBfYlWmDC8 (Shape: (768,), Type: float32)
# Dataset: 5noS6qGxcbM (Shape: (768,), Type: float32)
# Dataset: 5qfoeuQFFHw (Shape: (768,), Type: float32)
# Dataset: 5ttoICpH0Vc (Shape: (768,), Type: float32)
# Dataset: 5x1FeyWYp9s (Shape: (768,), Type: float32)
# Dataset: 5xx4Ha3kGtg (Shape: (768,), Type: float32)
# Dataset: 5yCSPi05MyA (Shape: (768,), Type: float32)
# Dataset: 5yGuDDemqaw (Shape: (768,), Type: float32)
# Dataset: 62tZR_Z_y08 (Shape: (768,), Type: float32)
# Dataset: 6BGmQ21EekY (Shape: (768,), Type: float32)
# Dataset: 6DI_C-xXcOQ (Shape: (768,), Type: float32)
# Dataset: 6GpeTJqqtG4 (Shape: (768,), Type: float32)
# Dataset: 6K7Xjdfc0bA (Shape: (768,), Type: float32)
# Dataset: 6Kfqy-8C3o0 (Shape: (768,), Type: float32)
# Dataset: 6M6cpjP7GIo (Shape: (768,), Type: float32)
# Dataset: 6QB5kS_JcuU (Shape: (768,), Type: float32)
# Dataset: 6U6MOfuFX-Q (Shape: (768,), Type: float32)
# Dataset: 6iGsAYTmnLg (Shape: (768,), Type: float32)
# Dataset: 6nX0100wUB0 (Shape: (768,), Type: float32)
# Dataset: 77DXn43fhVw (Shape: (768,), Type: float32)
# Dataset: 79kT7fUtLD0 (Shape: (768,), Type: float32)
# Dataset: 7Dxxk1az9Uo (Shape: (768,), Type: float32)
# Dataset: 7IrB1OE9Blo (Shape: (768,), Type: float32)
# Dataset: 7JOey0CIgMM (Shape: (768,), Type: float32)
# Dataset: 7LhZupa1Bng (Shape: (768,), Type: float32)
# Dataset: 7T5KMMZfc_U (Shape: (768,), Type: float32)
# Dataset: 7TY3DFSCrOc (Shape: (768,), Type: float32)
# Dataset: 7_AiHZa026w (Shape: (768,), Type: float32)
# Dataset: 7_OiqaOaeNc (Shape: (768,), Type: float32)
# Dataset: 7eI5BfzRCY4 (Shape: (768,), Type: float32)
# Dataset: 7iMvnj_UBqc (Shape: (768,), Type: float32)
# Dataset: 7mGr4Uc7ebA (Shape: (768,), Type: float32)
# Dataset: 7nUDA-4vD9g (Shape: (768,), Type: float32)
# Dataset: 7rN0Kk3eUSo (Shape: (768,), Type: float32)
# Dataset: 7s3dzArIVok (Shape: (768,), Type: float32)
# Dataset: 7y9stFHCvEY (Shape: (768,), Type: float32)
# Dataset: 885EiuL9GKg (Shape: (768,), Type: float32)
# Dataset: 89OqkIyNnfQ (Shape: (768,), Type: float32)
# Dataset: 8DlxO2frMPE (Shape: (768,), Type: float32)
# Dataset: 8JhRzlsZPas (Shape: (768,), Type: float32)
# Dataset: 8X26PR7abAU (Shape: (768,), Type: float32)
# Dataset: 8XkrkBt-8LQ (Shape: (768,), Type: float32)
# Dataset: 8aegfjXaTmY (Shape: (768,), Type: float32)
# Dataset: 8kzZwPsHkfo (Shape: (768,), Type: float32)
# Dataset: 8mDtsn0yrsA (Shape: (768,), Type: float32)
# Dataset: 8qQg4bvTlho (Shape: (768,), Type: float32)
# Dataset: 9-tYZkJ2p54 (Shape: (768,), Type: float32)
# Dataset: 93TnnyxGBqI (Shape: (768,), Type: float32)
# Dataset: 93njceSaOMM (Shape: (768,), Type: float32)
# Dataset: 93qTzU2bNh8 (Shape: (768,), Type: float32)
# Dataset: 9BOOv6NNnP0 (Shape: (768,), Type: float32)
# Dataset: 9Eont_yEGZs (Shape: (768,), Type: float32)
# Dataset: 9IUZkug8qo8 (Shape: (768,), Type: float32)
# Dataset: 9Okpnw0Ktt8 (Shape: (768,), Type: float32)
# Dataset: 9WY5gDBR0gM (Shape: (768,), Type: float32)
# Dataset: 9Wfswn2lkAo (Shape: (768,), Type: float32)
# Dataset: 9ZY9i9-hoQM (Shape: (768,), Type: float32)
# Dataset: 9_T2VQgL2XY (Shape: (768,), Type: float32)
# Dataset: 9knEvoHQfEw (Shape: (768,), Type: float32)
# Dataset: 9nOc2GqCQ2Y (Shape: (768,), Type: float32)
# Dataset: 9rj02jWyo94 (Shape: (768,), Type: float32)
# Dataset: 9smHLhj75CU (Shape: (768,), Type: float32)
# Dataset: 9tIcnydrwFY (Shape: (768,), Type: float32)
# Dataset: 9zZLmOA4OsA (Shape: (768,), Type: float32)
# Dataset: A4iXXQr7tqw (Shape: (768,), Type: float32)
# Dataset: AC9SF7TOyHQ (Shape: (768,), Type: float32)
# Dataset: AFCv59zRbGo (Shape: (768,), Type: float32)
# Dataset: ANigqhwwafs (Shape: (768,), Type: float32)
# Dataset: AV3CrPe-1q0 (Shape: (768,), Type: float32)
# Dataset: AX-qpuOuDVg (Shape: (768,), Type: float32)
# Dataset: AZMg4vFcRQs (Shape: (768,), Type: float32)
# Dataset: AZxn9md_aZI (Shape: (768,), Type: float32)
# Dataset: AjAJNPCQ1Fs (Shape: (768,), Type: float32)
# Dataset: Ak1dPU8uXiE (Shape: (768,), Type: float32)
# Dataset: AqKpGR4EocU (Shape: (768,), Type: float32)
# Dataset: AuYaiXT_1tM (Shape: (768,), Type: float32)
# Dataset: AzGePmv0GD8 (Shape: (768,), Type: float32)
# Dataset: B1QVeR_p7WQ (Shape: (768,), Type: float32)
# Dataset: B4jUZUgKhFQ (Shape: (768,), Type: float32)
# Dataset: B5uw3qZ04NY (Shape: (768,), Type: float32)
# Dataset: BCyz82L_61E (Shape: (768,), Type: float32)
# Dataset: BGyfOMCRBn0 (Shape: (768,), Type: float32)
# Dataset: BNxai8Y9IXg (Shape: (768,), Type: float32)
# Dataset: BRBSfKmp3vs (Shape: (768,), Type: float32)
# Dataset: BV1Nyf_u1AA (Shape: (768,), Type: float32)
# Dataset: BWT3i-fgw0s (Shape: (768,), Type: float32)
# Dataset: Bf6I7N-DC7g (Shape: (768,), Type: float32)
# Dataset: BiPY5_H9EIw (Shape: (768,), Type: float32)
# Dataset: Bl6eouVUsCI (Shape: (768,), Type: float32)
# Dataset: BnnCQlp2msk (Shape: (768,), Type: float32)
# Dataset: Buutvk0mHXY (Shape: (768,), Type: float32)
# Dataset: C0NVo07t9UI (Shape: (768,), Type: float32)
# Dataset: C7ke6vWUu18 (Shape: (768,), Type: float32)
# Dataset: CDiosBMzR_c (Shape: (768,), Type: float32)
# Dataset: CJGNkuaveUE (Shape: (768,), Type: float32)
# Dataset: CVxgFZixwlg (Shape: (768,), Type: float32)
# Dataset: CkN1FvtBg2k (Shape: (768,), Type: float32)
# Dataset: CmpDJs0Mjj0 (Shape: (768,), Type: float32)
# Dataset: CmssRVrBMxU (Shape: (768,), Type: float32)
# Dataset: CqgXhXx-EAk (Shape: (768,), Type: float32)
# Dataset: CuscvBChOqM (Shape: (768,), Type: float32)
# Dataset: CwdGYMM2bHM (Shape: (768,), Type: float32)
# Dataset: D1IshjFWDJk (Shape: (768,), Type: float32)
# Dataset: DA2JIQh96iI (Shape: (768,), Type: float32)
# Dataset: DIlG9aSMCpg (Shape: (768,), Type: float32)
# Dataset: DKtjBqJ4NxA (Shape: (768,), Type: float32)
# Dataset: DNt7PNTuePY (Shape: (768,), Type: float32)
# Dataset: DRTuzzBTrGs (Shape: (768,), Type: float32)
# Dataset: DUbplahEBfQ (Shape: (768,), Type: float32)
# Dataset: DWjJlErBPX4 (Shape: (768,), Type: float32)
# Dataset: DXjOOS4zAq4 (Shape: (768,), Type: float32)
# Dataset: DcfEOMgI_5o (Shape: (768,), Type: float32)
# Dataset: DcpIpj7RbxQ (Shape: (768,), Type: float32)
# Dataset: DjNVqYjp3E4 (Shape: (768,), Type: float32)
# Dataset: Dkj-8VuWNJk (Shape: (768,), Type: float32)
# Dataset: DrIsPRZL578 (Shape: (768,), Type: float32)
# Dataset: Dw_6CTZVb7c (Shape: (768,), Type: float32)
# Dataset: DxCjqhDD7X4 (Shape: (768,), Type: float32)
# Dataset: DxRzEdg0p4Q (Shape: (768,), Type: float32)
# Dataset: E-F92GOLVcU (Shape: (768,), Type: float32)
# Dataset: E5aXYsk787U (Shape: (768,), Type: float32)
# Dataset: E9uah5ldjvo (Shape: (768,), Type: float32)
# Dataset: EB74RP-oZqE (Shape: (768,), Type: float32)
# Dataset: EF2WHYOjGhE (Shape: (768,), Type: float32)
# Dataset: EFgCZDRkacU (Shape: (768,), Type: float32)
# Dataset: EN0JaJN_fwU (Shape: (768,), Type: float32)
# Dataset: ENC7ueK93Ow (Shape: (768,), Type: float32)
# Dataset: EOQeU_6vbeg (Shape: (768,), Type: float32)
# Dataset: EY2tpd1CejA (Shape: (768,), Type: float32)
# Dataset: Ece-FTMuKFU (Shape: (768,), Type: float32)
# Dataset: Ed__PtLnaeo (Shape: (768,), Type: float32)
# Dataset: EqFFgltjVbg (Shape: (768,), Type: float32)
# Dataset: F58XJgGx3DY (Shape: (768,), Type: float32)
# Dataset: F7bAUwj2HEs (Shape: (768,), Type: float32)
# Dataset: F9vKkW_NNjE (Shape: (768,), Type: float32)
# Dataset: FCJx1uV38ZQ (Shape: (768,), Type: float32)
# Dataset: FFnyDGETjzA (Shape: (768,), Type: float32)
# Dataset: FGWPKiI0YJQ (Shape: (768,), Type: float32)
# Dataset: FM26ZXjPL_4 (Shape: (768,), Type: float32)
# Dataset: FPYjy-ZWB-c (Shape: (768,), Type: float32)
# Dataset: FQoR9fu-CIE (Shape: (768,), Type: float32)
# Dataset: FS3hFDdeX30 (Shape: (768,), Type: float32)
# Dataset: FT1C1QdiMhw (Shape: (768,), Type: float32)
# Dataset: FTV4FUlcIwQ (Shape: (768,), Type: float32)
# Dataset: FYZrWswLpu0 (Shape: (768,), Type: float32)
# Dataset: FZlm1ledK-I (Shape: (768,), Type: float32)
# Dataset: FcFtBqXUud0 (Shape: (768,), Type: float32)
# Dataset: FgF-RJYNzzY (Shape: (768,), Type: float32)
# Dataset: FyuQ13ZZNIQ (Shape: (768,), Type: float32)
# Dataset: G-lDaFtb7eE (Shape: (768,), Type: float32)
# Dataset: G0rXUr-msX0 (Shape: (768,), Type: float32)
# Dataset: G1BREAJI3E0 (Shape: (768,), Type: float32)
# Dataset: G2Mbj06Ns2Y (Shape: (768,), Type: float32)
# Dataset: G2ngOQwMMek (Shape: (768,), Type: float32)
# Dataset: G5aoRyZ-QtM (Shape: (768,), Type: float32)
# Dataset: GEAh4nF90iw (Shape: (768,), Type: float32)
# Dataset: GHKfMt_4V7U (Shape: (768,), Type: float32)
# Dataset: GKuQDM9OlAQ (Shape: (768,), Type: float32)
# Dataset: GRrLWGMz5XY (Shape: (768,), Type: float32)
# Dataset: GU1zIn2BRN0 (Shape: (768,), Type: float32)
# Dataset: GfHOoFVUk9Y (Shape: (768,), Type: float32)
# Dataset: Gh9kc9DiDnE (Shape: (768,), Type: float32)
# Dataset: GjPCk494e5Q (Shape: (768,), Type: float32)
# Dataset: GtSNSaW9IRI (Shape: (768,), Type: float32)
# Dataset: H1JCgM_LHAg (Shape: (768,), Type: float32)
# Dataset: H44YauhtGPU (Shape: (768,), Type: float32)
# Dataset: H6ImGh1Xolc (Shape: (768,), Type: float32)
# Dataset: H7tyPUAH1lo (Shape: (768,), Type: float32)
# Dataset: H92n6qsNHbY (Shape: (768,), Type: float32)
# Dataset: HH37JTBpi2A (Shape: (768,), Type: float32)
# Dataset: HUKu_iqYDOA (Shape: (768,), Type: float32)
# Dataset: HWe802TQAG0 (Shape: (768,), Type: float32)
# Dataset: HfKAC6eOlXg (Shape: (768,), Type: float32)
# Dataset: HhBAeTBIj0U (Shape: (768,), Type: float32)
# Dataset: HrIyLLIHrDA (Shape: (768,), Type: float32)
# Dataset: I-AhUVGpGoU (Shape: (768,), Type: float32)
# Dataset: I-OaeRbZtk8 (Shape: (768,), Type: float32)
# Dataset: I3znSbbu9IU (Shape: (768,), Type: float32)
# Dataset: I4tqrGqT_b0 (Shape: (768,), Type: float32)
# Dataset: IEA7PR8i5Gc (Shape: (768,), Type: float32)
# Dataset: IGFdF06VVF8 (Shape: (768,), Type: float32)
# Dataset: IGVwlBTTqYM (Shape: (768,), Type: float32)
# Dataset: IVRy-Jac660 (Shape: (768,), Type: float32)
# Dataset: IWQriJ_Nebs (Shape: (768,), Type: float32)
# Dataset: Ib8uNldNd-0 (Shape: (768,), Type: float32)
# Dataset: Ihd-NwI030c (Shape: (768,), Type: float32)
# Dataset: IiMacKBYPZg (Shape: (768,), Type: float32)
# Dataset: IiQlYWhL_UI (Shape: (768,), Type: float32)
# Dataset: IjrWOZby8s8 (Shape: (768,), Type: float32)
# Dataset: Ik8q8LDqWiE (Shape: (768,), Type: float32)
# Dataset: IkQ_uPNWp28 (Shape: (768,), Type: float32)
# Dataset: JDbwEQG2cqI (Shape: (768,), Type: float32)
# Dataset: JKMpRikJeLI (Shape: (768,), Type: float32)
# Dataset: JQoNhRN9CiI (Shape: (768,), Type: float32)
# Dataset: Jf7jVM7NoVE (Shape: (768,), Type: float32)
# Dataset: JjRx9IJSTMw (Shape: (768,), Type: float32)
# Dataset: Jo1OjI4Yfv8 (Shape: (768,), Type: float32)
# Dataset: JxRj80eLkMc (Shape: (768,), Type: float32)
# Dataset: JyTf7wR8vWI (Shape: (768,), Type: float32)
# Dataset: K2NNznJJadY (Shape: (768,), Type: float32)
# Dataset: K44KlE3sSMM (Shape: (768,), Type: float32)
# Dataset: K5IU4bPS_S8 (Shape: (768,), Type: float32)
# Dataset: K6Kkwi0nfHg (Shape: (768,), Type: float32)
# Dataset: KEc0SGkBDJ4 (Shape: (768,), Type: float32)
# Dataset: KJtmyW2urUk (Shape: (768,), Type: float32)
# Dataset: KKzWTwJwrGc (Shape: (768,), Type: float32)
# Dataset: KXTBm9eUiko (Shape: (768,), Type: float32)
# Dataset: KZt-mGmTpZI (Shape: (768,), Type: float32)
# Dataset: KekChFdIe00 (Shape: (768,), Type: float32)
# Dataset: KiOiYYsMcM4 (Shape: (768,), Type: float32)
# Dataset: Km2lbJKGAqA (Shape: (768,), Type: float32)
# Dataset: Kv_9PD-_akA (Shape: (768,), Type: float32)
# Dataset: KwnTYy2p0AE (Shape: (768,), Type: float32)
# Dataset: KxoJQx_MgAc (Shape: (768,), Type: float32)
# Dataset: L2GbnErVDqk (Shape: (768,), Type: float32)
# Dataset: LE0TUN0Po7I (Shape: (768,), Type: float32)
# Dataset: LF0dTioXk3A (Shape: (768,), Type: float32)
# Dataset: LIIzjJjsW8s (Shape: (768,), Type: float32)
# Dataset: LMViEmB4_Fk (Shape: (768,), Type: float32)
# Dataset: LOVgTjeg4fY (Shape: (768,), Type: float32)
# Dataset: LVvJj9sDilQ (Shape: (768,), Type: float32)
# Dataset: LWWG1eKmylY (Shape: (768,), Type: float32)
# Dataset: LauRAuoFO0U (Shape: (768,), Type: float32)
# Dataset: LbkjkJzREd4 (Shape: (768,), Type: float32)
# Dataset: LiYdMadk89Q (Shape: (768,), Type: float32)
# Dataset: LkimMjwfjrQ (Shape: (768,), Type: float32)
# Dataset: LruyfJJT7qY (Shape: (768,), Type: float32)
# Dataset: LszhBmIWjeE (Shape: (768,), Type: float32)
# Dataset: LwELqrqsf_o (Shape: (768,), Type: float32)
# Dataset: Lxuqbh2tjTs (Shape: (768,), Type: float32)
# Dataset: LyfG5cnkuEI (Shape: (768,), Type: float32)
# Dataset: LzJEXl2ie4E (Shape: (768,), Type: float32)
# Dataset: M-HCaHXzQRY (Shape: (768,), Type: float32)
# Dataset: M9WaDhm3bE0 (Shape: (768,), Type: float32)
# Dataset: MBSxl8y36zg (Shape: (768,), Type: float32)
# Dataset: MCXx5saaKOk (Shape: (768,), Type: float32)
# Dataset: MGwI25DNrHU (Shape: (768,), Type: float32)
# Dataset: MQEwJdhfddk (Shape: (768,), Type: float32)
# Dataset: MWc0I1-Sfj4 (Shape: (768,), Type: float32)
# Dataset: MZaX-RbQ7ic (Shape: (768,), Type: float32)
# Dataset: MbbKc8GJtFA (Shape: (768,), Type: float32)
# Dataset: MdI5DrJ6V3k (Shape: (768,), Type: float32)
# Dataset: Me3eSvA2K9k (Shape: (768,), Type: float32)
# Dataset: Mg7RrLU3Uq8 (Shape: (768,), Type: float32)
# Dataset: MmKlIGkxGyM (Shape: (768,), Type: float32)
# Dataset: MoOwbXap6LM (Shape: (768,), Type: float32)
# Dataset: MuWwCUXGzWE (Shape: (768,), Type: float32)
# Dataset: N0gaRYJH5GE (Shape: (768,), Type: float32)
# Dataset: N3U5ed3dRAE (Shape: (768,), Type: float32)
# Dataset: N3qEvEGFdKE (Shape: (768,), Type: float32)
# Dataset: N7UtdTiuO3w (Shape: (768,), Type: float32)
# Dataset: NAGgo5AtHzE (Shape: (768,), Type: float32)
# Dataset: NGtMNsci-zk (Shape: (768,), Type: float32)
# Dataset: NInjsGq2yCA (Shape: (768,), Type: float32)
# Dataset: NQhm9xmVHdU (Shape: (768,), Type: float32)
# Dataset: NTGOA6lPP5w (Shape: (768,), Type: float32)
# Dataset: NZ-u1BXI0YQ (Shape: (768,), Type: float32)
# Dataset: Nc_b69ag6Eo (Shape: (768,), Type: float32)
# Dataset: NnDKut3pxoU (Shape: (768,), Type: float32)
# Dataset: O6Obigg85oo (Shape: (768,), Type: float32)
# Dataset: OOMIZUsKlmg (Shape: (768,), Type: float32)
# Dataset: OToWh3nrWn8 (Shape: (768,), Type: float32)
# Dataset: OroiRWIR2gQ (Shape: (768,), Type: float32)
# Dataset: Ot5G0Nh6EyY (Shape: (768,), Type: float32)
# Dataset: OzP8k0R-USw (Shape: (768,), Type: float32)
# Dataset: P6fVrC-RQLg (Shape: (768,), Type: float32)
# Dataset: PHHgumL4rUI (Shape: (768,), Type: float32)
# Dataset: PJlmYh27MHg (Shape: (768,), Type: float32)
# Dataset: PMjbPEGDJ7w (Shape: (768,), Type: float32)
# Dataset: POR5t4hjtPg (Shape: (768,), Type: float32)
# Dataset: PSWgZzUr_Yw (Shape: (768,), Type: float32)
# Dataset: PahVp7p3XHg (Shape: (768,), Type: float32)
# Dataset: Pg_mCxaEa10 (Shape: (768,), Type: float32)
# Dataset: PjJzOpe9xEg (Shape: (768,), Type: float32)
# Dataset: PkCxda_9xRc (Shape: (768,), Type: float32)
# Dataset: PlBpNTEaRTI (Shape: (768,), Type: float32)
# Dataset: PoaOwSPJPHw (Shape: (768,), Type: float32)
# Dataset: Pq2Z7Qf45gM (Shape: (768,), Type: float32)
# Dataset: PsqrgV2RCCM (Shape: (768,), Type: float32)
# Dataset: PuVXyMNeXOk (Shape: (768,), Type: float32)
# Dataset: PzTICfN0A-4 (Shape: (768,), Type: float32)
# Dataset: Q0UDJuPozw8 (Shape: (768,), Type: float32)
# Dataset: Q0xqrvefO7Q (Shape: (768,), Type: float32)
# Dataset: Q1Yz3J6OGQQ (Shape: (768,), Type: float32)
# Dataset: Q1khILbP8yU (Shape: (768,), Type: float32)
# Dataset: QB9AY9Em4To (Shape: (768,), Type: float32)
# Dataset: QRqXBsgnYok (Shape: (768,), Type: float32)
# Dataset: R2lhQCxKx_Y (Shape: (768,), Type: float32)
# Dataset: RIN6AtTxFgE (Shape: (768,), Type: float32)
# Dataset: RUE4v1rUpSM (Shape: (768,), Type: float32)
# Dataset: RZa79QGDeo8 (Shape: (768,), Type: float32)
# Dataset: RfvKvTlQHuw (Shape: (768,), Type: float32)
# Dataset: RgubwsCVg1o (Shape: (768,), Type: float32)
# Dataset: RtRffVRFz6M (Shape: (768,), Type: float32)
# Dataset: Rtf8uPmgq0A (Shape: (768,), Type: float32)
# Dataset: Ru2Mvkf9dL8 (Shape: (768,), Type: float32)
# Dataset: S-6xoT5Z2nA (Shape: (768,), Type: float32)
# Dataset: S-EfnfP_cGY (Shape: (768,), Type: float32)
# Dataset: S-xuQp2fW7I (Shape: (768,), Type: float32)
# Dataset: S4PYI6TzqYk (Shape: (768,), Type: float32)
# Dataset: S7OWoc-j8qQ (Shape: (768,), Type: float32)
# Dataset: SEzrTYKabwI (Shape: (768,), Type: float32)
# Dataset: SF5EacV4NI0 (Shape: (768,), Type: float32)
# Dataset: SLL5ziDWc6k (Shape: (768,), Type: float32)
# Dataset: SMJqQ3VrcCA (Shape: (768,), Type: float32)
# Dataset: SQrD5lkN18o (Shape: (768,), Type: float32)
# Dataset: SR5BfQ4rEqQ (Shape: (768,), Type: float32)
# Dataset: SW-1sk_U8vU (Shape: (768,), Type: float32)
# Dataset: SZ3oe7dJdMc (Shape: (768,), Type: float32)
# Dataset: SjbUk89pY7Y (Shape: (768,), Type: float32)
# Dataset: SldtDNNTA2s (Shape: (768,), Type: float32)
# Dataset: SswN494Jxr8 (Shape: (768,), Type: float32)
# Dataset: Sy7YnrVXudg (Shape: (768,), Type: float32)
# Dataset: SyQSH3XmQCE (Shape: (768,), Type: float32)
# Dataset: T4Sk7RsIQd0 (Shape: (768,), Type: float32)
# Dataset: T8oTlWwAPFI (Shape: (768,), Type: float32)
# Dataset: T9tQanQSgQM (Shape: (768,), Type: float32)
# Dataset: TEodx0CTTgE (Shape: (768,), Type: float32)
# Dataset: TJj7YqhNxiw (Shape: (768,), Type: float32)
# Dataset: TKpXTy-sCxg (Shape: (768,), Type: float32)
# Dataset: TQXuazYI_YU (Shape: (768,), Type: float32)
# Dataset: TWjtzvFrA8c (Shape: (768,), Type: float32)
# Dataset: TZ2ryw04fx4 (Shape: (768,), Type: float32)
# Dataset: TZyl-21DgPo (Shape: (768,), Type: float32)
# Dataset: Tanjysfo1SE (Shape: (768,), Type: float32)
# Dataset: TbFYMfIpRss (Shape: (768,), Type: float32)
# Dataset: Tcwz8-EfFYE (Shape: (768,), Type: float32)
# Dataset: TeGaTTIBv1Y (Shape: (768,), Type: float32)
# Dataset: TiJBxtM5iKw (Shape: (768,), Type: float32)
# Dataset: TotAfd4ercA (Shape: (768,), Type: float32)
# Dataset: Tr90d0ZcrCU (Shape: (768,), Type: float32)
# Dataset: TsIQj8gZeo0 (Shape: (768,), Type: float32)
# Dataset: Tt2oL1sVVhM (Shape: (768,), Type: float32)
# Dataset: TuQLFcJ8Eyw (Shape: (768,), Type: float32)
# Dataset: TvFwTMU0vyY (Shape: (768,), Type: float32)
# Dataset: UBNLrL7RvJM (Shape: (768,), Type: float32)
# Dataset: UJ12I9sHqK8 (Shape: (768,), Type: float32)
# Dataset: ULCyXL8cTFU (Shape: (768,), Type: float32)
# Dataset: UUzW7NqutUg (Shape: (768,), Type: float32)
# Dataset: UZnEqDr9PKE (Shape: (768,), Type: float32)
# Dataset: UbwxGgR-EAM (Shape: (768,), Type: float32)
# Dataset: UgiK8333Np0 (Shape: (768,), Type: float32)
# Dataset: Uk280jVuH1w (Shape: (768,), Type: float32)
# Dataset: UtS2awRAf5E (Shape: (768,), Type: float32)
# Dataset: VEB-OoUrNuk (Shape: (768,), Type: float32)
# Dataset: VGcOGt-OV7s (Shape: (768,), Type: float32)
# Dataset: VMVzQ8rW53Q (Shape: (768,), Type: float32)
# Dataset: VNI6movTCuQ (Shape: (768,), Type: float32)
# Dataset: VY4Bo_Mcws4 (Shape: (768,), Type: float32)
# Dataset: VYMQZsZUxeA (Shape: (768,), Type: float32)
# Dataset: VZrBzpfh6hM (Shape: (768,), Type: float32)
# Dataset: VdlxHA_WLn4 (Shape: (768,), Type: float32)
# Dataset: Vh7XH68xWKw (Shape: (768,), Type: float32)
# Dataset: VhdCpMoShM4 (Shape: (768,), Type: float32)
# Dataset: Vkrb_0DiD4E (Shape: (768,), Type: float32)
# Dataset: Vro5qtVA4PE (Shape: (768,), Type: float32)
# Dataset: Vs0CShp6HFA (Shape: (768,), Type: float32)
# Dataset: Vyrr1vSRYjs (Shape: (768,), Type: float32)
# Dataset: WFhKV35sbCE (Shape: (768,), Type: float32)
# Dataset: WL4kf1SZAE8 (Shape: (768,), Type: float32)
# Dataset: WNZNGn_nkOU (Shape: (768,), Type: float32)
# Dataset: WRlIDIu2qpg (Shape: (768,), Type: float32)
# Dataset: WSUWoBeJ6dg (Shape: (768,), Type: float32)
# Dataset: WXUGWaYOnUs (Shape: (768,), Type: float32)
# Dataset: WZ6p4t3StSc (Shape: (768,), Type: float32)
# Dataset: W_0WRTR2vSc (Shape: (768,), Type: float32)
# Dataset: WbW8GgAWKi8 (Shape: (768,), Type: float32)
# Dataset: Wc_pikEIkcQ (Shape: (768,), Type: float32)
# Dataset: Wl6COOA3V6Y (Shape: (768,), Type: float32)
# Dataset: WlwLa7Jh3HY (Shape: (768,), Type: float32)
# Dataset: WsffSfKc-mw (Shape: (768,), Type: float32)
# Dataset: WtnTZSJndPc (Shape: (768,), Type: float32)
# Dataset: Wzp2rpe06j8 (Shape: (768,), Type: float32)
# Dataset: X-3TvjRKYPI (Shape: (768,), Type: float32)
# Dataset: X6UG7H2dcos (Shape: (768,), Type: float32)
# Dataset: XDO8OYnmkNY (Shape: (768,), Type: float32)
# Dataset: XHuo5etrwvY (Shape: (768,), Type: float32)
# Dataset: XIJ-TpmNlI0 (Shape: (768,), Type: float32)
# Dataset: XN7uqQnAxIc (Shape: (768,), Type: float32)
# Dataset: XNAVsV-Jqfg (Shape: (768,), Type: float32)
# Dataset: XOnuxo70q9Q (Shape: (768,), Type: float32)
# Dataset: XTjTXskLQO0 (Shape: (768,), Type: float32)
# Dataset: XX8y_mQIewU (Shape: (768,), Type: float32)
# Dataset: XcNYS8j9Qkg (Shape: (768,), Type: float32)
# Dataset: Xi3P8vUveVQ (Shape: (768,), Type: float32)
# Dataset: XmGOiqQm9B0 (Shape: (768,), Type: float32)
# Dataset: Xon0bfX3L1g (Shape: (768,), Type: float32)
# Dataset: YDDzjijc6jY (Shape: (768,), Type: float32)
# Dataset: YER_g7jph94 (Shape: (768,), Type: float32)
# Dataset: YFnErcVxB-Q (Shape: (768,), Type: float32)
# Dataset: YPXkzktz5oA (Shape: (768,), Type: float32)
# Dataset: YRruOzr9_w0 (Shape: (768,), Type: float32)
# Dataset: YcbZKza_zUg (Shape: (768,), Type: float32)
# Dataset: YgcSs9Qt2vU (Shape: (768,), Type: float32)
# Dataset: YgdWrHFx0I0 (Shape: (768,), Type: float32)
# Dataset: YjfLp0bll5U (Shape: (768,), Type: float32)
# Dataset: Yjs3BLAsvOc (Shape: (768,), Type: float32)
# Dataset: YkYqKiASqJM (Shape: (768,), Type: float32)
# Dataset: Yky4QtRX_DI (Shape: (768,), Type: float32)
# Dataset: Ypa0nma0aSs (Shape: (768,), Type: float32)
# Dataset: YsMdkGG2b0k (Shape: (768,), Type: float32)
# Dataset: YwrX990kW9k (Shape: (768,), Type: float32)
# Dataset: Z5Hmi5x6JA8 (Shape: (768,), Type: float32)
# Dataset: ZCTqZhZRYl0 (Shape: (768,), Type: float32)
# Dataset: ZJF_1LQbKiM (Shape: (768,), Type: float32)
# Dataset: ZLmRWzBjbtU (Shape: (768,), Type: float32)
# Dataset: ZMZxDJb5V8o (Shape: (768,), Type: float32)
# Dataset: ZZyXtEMFfaw (Shape: (768,), Type: float32)
# Dataset: ZbPoAOc_iKw (Shape: (768,), Type: float32)
# Dataset: ZkynnGqL7QM (Shape: (768,), Type: float32)
# Dataset: ZlFSjq7eU4Y (Shape: (768,), Type: float32)
# Dataset: ZmdWPv5R_J8 (Shape: (768,), Type: float32)
# Dataset: Zz-mpgYNUW8 (Shape: (768,), Type: float32)
# Dataset: _7vyrudcgOQ (Shape: (768,), Type: float32)
# Dataset: _LvUmxUqPTo (Shape: (768,), Type: float32)
# Dataset: _OiXT87RhvA (Shape: (768,), Type: float32)
# Dataset: _SQ4ogstDVE (Shape: (768,), Type: float32)
# Dataset: _WWIiTlGyYQ (Shape: (768,), Type: float32)
# Dataset: _ZJUuDLqjzU (Shape: (768,), Type: float32)
# Dataset: _bJYiiCvPW4 (Shape: (768,), Type: float32)
# Dataset: _emU23tTUAw (Shape: (768,), Type: float32)
# Dataset: _fJArvSVqEo (Shape: (768,), Type: float32)
# Dataset: _hyXwvNIKZM (Shape: (768,), Type: float32)
# Dataset: _oyt0p3Kikg (Shape: (768,), Type: float32)
# Dataset: _t1yxHW97xE (Shape: (768,), Type: float32)
# Dataset: _t4L-ZdoEr8 (Shape: (768,), Type: float32)
# Dataset: _yy4qamWAmk (Shape: (768,), Type: float32)
# Dataset: a2qE4hG9XCk (Shape: (768,), Type: float32)
# Dataset: a6CsW4dCk_8 (Shape: (768,), Type: float32)
# Dataset: a81pNygdAXw (Shape: (768,), Type: float32)
# Dataset: a8mImo0aNDo (Shape: (768,), Type: float32)
# Dataset: a8xs3O-NwsY (Shape: (768,), Type: float32)
# Dataset: aDJgv1iARPg (Shape: (768,), Type: float32)
# Dataset: aDU5CcINqyI (Shape: (768,), Type: float32)
# Dataset: aL4dQo8iBLo (Shape: (768,), Type: float32)
# Dataset: aOg9IcxuV2g (Shape: (768,), Type: float32)
# Dataset: aP22KbKvaMg (Shape: (768,), Type: float32)
# Dataset: abXL2HrEjyE (Shape: (768,), Type: float32)
# Dataset: ah_Egywb780 (Shape: (768,), Type: float32)
# Dataset: ahuPW6_t-z0 (Shape: (768,), Type: float32)
# Dataset: ajBHZKoKYbU (Shape: (768,), Type: float32)
# Dataset: arJc5qABgO8 (Shape: (768,), Type: float32)
# Dataset: avXk2EamFs4 (Shape: (768,), Type: float32)
# Dataset: axcECZzlPVI (Shape: (768,), Type: float32)
# Dataset: b-QlCUByMcE (Shape: (768,), Type: float32)
# Dataset: b2dewDwIQyM (Shape: (768,), Type: float32)
# Dataset: b6vOp7_rI6Q (Shape: (768,), Type: float32)
# Dataset: bFWMtZmjwR4 (Shape: (768,), Type: float32)
# Dataset: bS9N8dEdZCQ (Shape: (768,), Type: float32)
# Dataset: bSdm_eA1Css (Shape: (768,), Type: float32)
# Dataset: bXzp-98u468 (Shape: (768,), Type: float32)
# Dataset: bZhBhpm6m_A (Shape: (768,), Type: float32)
# Dataset: bg9SuuzPdVE (Shape: (768,), Type: float32)
# Dataset: bwzuMk8SRzY (Shape: (768,), Type: float32)
# Dataset: c-unYxWW6ws (Shape: (768,), Type: float32)
# Dataset: c35RsjYzAhY (Shape: (768,), Type: float32)
# Dataset: c5Re3lGYUA0 (Shape: (768,), Type: float32)
# Dataset: c5aNkzn_8Bc (Shape: (768,), Type: float32)
# Dataset: c9oE47YW6YM (Shape: (768,), Type: float32)
# Dataset: cEjo0ajod1M (Shape: (768,), Type: float32)
# Dataset: cFVtyYzs48I (Shape: (768,), Type: float32)
# Dataset: cKw1b2-4aeU (Shape: (768,), Type: float32)
# Dataset: cNW7dRdPPC8 (Shape: (768,), Type: float32)
# Dataset: cNqstBuw5ZY (Shape: (768,), Type: float32)
# Dataset: cbzkmMaYSNg (Shape: (768,), Type: float32)
# Dataset: chlwxs2dfVA (Shape: (768,), Type: float32)
# Dataset: ciL0tWi56tM (Shape: (768,), Type: float32)
# Dataset: cil6HFXlccw (Shape: (768,), Type: float32)
# Dataset: cqD8XBONBHY (Shape: (768,), Type: float32)
# Dataset: cw1dB9PxWzM (Shape: (768,), Type: float32)
# Dataset: cy2Xj8Pz2Tk (Shape: (768,), Type: float32)
# Dataset: czU3M9Ye268 (Shape: (768,), Type: float32)
# Dataset: d6HReoQl6Mo (Shape: (768,), Type: float32)
# Dataset: dEHht_iK6qY (Shape: (768,), Type: float32)
# Dataset: dKsDjpKr2Mk (Shape: (768,), Type: float32)
# Dataset: dLjNzwEULG8 (Shape: (768,), Type: float32)
# Dataset: dLpCZ8g5uK8 (Shape: (768,), Type: float32)
# Dataset: dQTwbSY0z_Q (Shape: (768,), Type: float32)
# Dataset: dSdY41CWixQ (Shape: (768,), Type: float32)
# Dataset: djIvmaYI9LQ (Shape: (768,), Type: float32)
# Dataset: dp2MR9fswWk (Shape: (768,), Type: float32)
# Dataset: dwykptqZBj0 (Shape: (768,), Type: float32)
# Dataset: eB-ldQkL--0 (Shape: (768,), Type: float32)
# Dataset: eFs_YLy3Ld8 (Shape: (768,), Type: float32)
# Dataset: eFzzQuYRw34 (Shape: (768,), Type: float32)
# Dataset: eKCkxzJFP5M (Shape: (768,), Type: float32)
# Dataset: eKrEVWGTuRg (Shape: (768,), Type: float32)
# Dataset: eSBnFu1YnrU (Shape: (768,), Type: float32)
# Dataset: eeGuOguh33o (Shape: (768,), Type: float32)
# Dataset: eeXePDLKsmU (Shape: (768,), Type: float32)
# Dataset: efNMnSL6Wlg (Shape: (768,), Type: float32)
# Dataset: ehv1cHqfQ-U (Shape: (768,), Type: float32)
# Dataset: evoa_UWUobI (Shape: (768,), Type: float32)
# Dataset: exCuIisMWl0 (Shape: (768,), Type: float32)
# Dataset: f4zl3CuJvt8 (Shape: (768,), Type: float32)
# Dataset: f6-8wpMn_8I (Shape: (768,), Type: float32)
# Dataset: fAiJAcgjWeQ (Shape: (768,), Type: float32)
# Dataset: fBlAMqoJ5BA (Shape: (768,), Type: float32)
# Dataset: fIh6HDeXKGY (Shape: (768,), Type: float32)
# Dataset: fNMtHosai08 (Shape: (768,), Type: float32)
# Dataset: fRCKKlTNxt8 (Shape: (768,), Type: float32)
# Dataset: fWPRhRM1V7I (Shape: (768,), Type: float32)
# Dataset: fdw_aFH3To4 (Shape: (768,), Type: float32)
# Dataset: fpKl9lrLfx0 (Shape: (768,), Type: float32)
# Dataset: fpXngRB-VTw (Shape: (768,), Type: float32)
# Dataset: frV4tvni8H0 (Shape: (768,), Type: float32)
# Dataset: fvHgXzOY12Y (Shape: (768,), Type: float32)
# Dataset: fxriLTLhyyY (Shape: (768,), Type: float32)
# Dataset: fzRk8ovZ06s (Shape: (768,), Type: float32)
# Dataset: gAM2Q7Sqlbk (Shape: (768,), Type: float32)
# Dataset: gI1_6ob3hio (Shape: (768,), Type: float32)
# Dataset: gKRyD4CSjto (Shape: (768,), Type: float32)
# Dataset: gNCAj7eS07I (Shape: (768,), Type: float32)
# Dataset: gP_GbzDWoY0 (Shape: (768,), Type: float32)
# Dataset: gQubL9r0qAQ (Shape: (768,), Type: float32)
# Dataset: gSHomdp3o2U (Shape: (768,), Type: float32)
# Dataset: gaoMc6MgvNA (Shape: (768,), Type: float32)
# Dataset: gi9EwdK-6L4 (Shape: (768,), Type: float32)
# Dataset: giiuqTdBSTc (Shape: (768,), Type: float32)
# Dataset: go4K4rCFjMQ (Shape: (768,), Type: float32)
# Dataset: gpLzES4A7zY (Shape: (768,), Type: float32)
# Dataset: gsGm2Ohl7x8 (Shape: (768,), Type: float32)
# Dataset: h1aJoWg4vGo (Shape: (768,), Type: float32)
# Dataset: h7ZUKB_zYQ0 (Shape: (768,), Type: float32)
# Dataset: h9HV76Jl2WE (Shape: (768,), Type: float32)
# Dataset: hFqDZ3vzyRw (Shape: (768,), Type: float32)
# Dataset: hHWcoaM_59E (Shape: (768,), Type: float32)
# Dataset: hK2Em4D7fhU (Shape: (768,), Type: float32)
# Dataset: hQUBid6LIPU (Shape: (768,), Type: float32)
# Dataset: hZPz4w3jLXI (Shape: (768,), Type: float32)
# Dataset: hgGi1ODlBBo (Shape: (768,), Type: float32)
# Dataset: hlWL5Az4pow (Shape: (768,), Type: float32)
# Dataset: hsBtuhWw7RM (Shape: (768,), Type: float32)
# Dataset: hsIdl6x2Lck (Shape: (768,), Type: float32)
# Dataset: htCHOTJBiSc (Shape: (768,), Type: float32)
# Dataset: huOZPQ6Hl2c (Shape: (768,), Type: float32)
# Dataset: hwTf9WurF4U (Shape: (768,), Type: float32)
# Dataset: i4M2tehIejI (Shape: (768,), Type: float32)
# Dataset: i5dTE5dgWOw (Shape: (768,), Type: float32)
# Dataset: i9DMpMCCxuE (Shape: (768,), Type: float32)
# Dataset: iB89FIStq7Y (Shape: (768,), Type: float32)
# Dataset: iEattbpjGG4 (Shape: (768,), Type: float32)
# Dataset: iGIooJXEu9E (Shape: (768,), Type: float32)
# Dataset: iU0CuPH7akM (Shape: (768,), Type: float32)
# Dataset: iVojYtEpstY (Shape: (768,), Type: float32)
# Dataset: i_SnR25Zoho (Shape: (768,), Type: float32)
# Dataset: iaTG4JflfqM (Shape: (768,), Type: float32)
# Dataset: ie6rKW_Giqc (Shape: (768,), Type: float32)
# Dataset: iktC8imMBnw (Shape: (768,), Type: float32)
# Dataset: ip1igmoPSD8 (Shape: (768,), Type: float32)
# Dataset: irhRobBI3BE (Shape: (768,), Type: float32)
# Dataset: irnju0G-lBg (Shape: (768,), Type: float32)
# Dataset: iw-0Y6HWb9Q (Shape: (768,), Type: float32)
# Dataset: ixljWVyPby0 (Shape: (768,), Type: float32)
# Dataset: j1dkwnqffaM (Shape: (768,), Type: float32)
# Dataset: j1tkwdfz7n4 (Shape: (768,), Type: float32)
# Dataset: j2ZsEQ4Fr4c (Shape: (768,), Type: float32)
# Dataset: j8yAjWvAqyM (Shape: (768,), Type: float32)
# Dataset: jJ4zpJxcw4o (Shape: (768,), Type: float32)
# Dataset: jYbI8iVYCpc (Shape: (768,), Type: float32)
# Dataset: jagJeaLXRRQ (Shape: (768,), Type: float32)
# Dataset: jbeyKcGqxyI (Shape: (768,), Type: float32)
# Dataset: jmFpZsBB53s (Shape: (768,), Type: float32)
# Dataset: jo-aQkgNMKQ (Shape: (768,), Type: float32)
# Dataset: jr60kvuKw3w (Shape: (768,), Type: float32)
# Dataset: jrf263yJwic (Shape: (768,), Type: float32)
# Dataset: kCxqmweKXZ0 (Shape: (768,), Type: float32)
# Dataset: kHTAJHod8-g (Shape: (768,), Type: float32)
# Dataset: kTXlnI1XaSY (Shape: (768,), Type: float32)
# Dataset: kWmntegbxMc (Shape: (768,), Type: float32)
# Dataset: kYlPy24WJzU (Shape: (768,), Type: float32)
# Dataset: kn5Sc8o9YTM (Shape: (768,), Type: float32)
# Dataset: ks32K99a1RU (Shape: (768,), Type: float32)
# Dataset: kx2FhY_akDY (Shape: (768,), Type: float32)
# Dataset: l-aUy9_L22o (Shape: (768,), Type: float32)
# Dataset: l0RkrxY9mH8 (Shape: (768,), Type: float32)
# Dataset: l84trT4b6yE (Shape: (768,), Type: float32)
# Dataset: lGqBJx2xbqQ (Shape: (768,), Type: float32)
# Dataset: lJ7F2kWLGuE (Shape: (768,), Type: float32)
# Dataset: lMtWWls4oas (Shape: (768,), Type: float32)
# Dataset: lNVb-ZNIO-A (Shape: (768,), Type: float32)
# Dataset: lVZNAyNWcgs (Shape: (768,), Type: float32)
# Dataset: lYxVM8oNxRM (Shape: (768,), Type: float32)
# Dataset: lp6ibYQN8vQ (Shape: (768,), Type: float32)
# Dataset: lyd4tC8LH1s (Shape: (768,), Type: float32)
# Dataset: m7_LwdyNsIQ (Shape: (768,), Type: float32)
# Dataset: m7xTvb-FAhQ (Shape: (768,), Type: float32)
# Dataset: mEzXLJL48nA (Shape: (768,), Type: float32)
# Dataset: mNCLMfXv7ek (Shape: (768,), Type: float32)
# Dataset: mVbGpzsuNjE (Shape: (768,), Type: float32)
# Dataset: mVqKHUtKh8Y (Shape: (768,), Type: float32)
# Dataset: mZwKEa09xTc (Shape: (768,), Type: float32)
# Dataset: mgr2tLYYha4 (Shape: (768,), Type: float32)
# Dataset: mqpQgFfidcA (Shape: (768,), Type: float32)
# Dataset: mzZgTmwmkfo (Shape: (768,), Type: float32)
# Dataset: n39lwOfvb2E (Shape: (768,), Type: float32)
# Dataset: n3Y6B_UKam0 (Shape: (768,), Type: float32)
# Dataset: nEGbOGGiENU (Shape: (768,), Type: float32)
# Dataset: nELxnSK1SHk (Shape: (768,), Type: float32)
# Dataset: nIW73heJdg4 (Shape: (768,), Type: float32)
# Dataset: nKDUDF3cgRA (Shape: (768,), Type: float32)
# Dataset: nRTjNEP6v2U (Shape: (768,), Type: float32)
# Dataset: nSJxx_KUEes (Shape: (768,), Type: float32)
# Dataset: nekzfohNwuY (Shape: (768,), Type: float32)
# Dataset: nfV87TgYH78 (Shape: (768,), Type: float32)
# Dataset: nimkNFEKUkY (Shape: (768,), Type: float32)
# Dataset: njHGa4f1LwY (Shape: (768,), Type: float32)
# Dataset: nkVUb4kdhig (Shape: (768,), Type: float32)
# Dataset: nprJvYKz3QQ (Shape: (768,), Type: float32)
# Dataset: nqJIAz0C5Ig (Shape: (768,), Type: float32)
# Dataset: ntsuIs20RW0 (Shape: (768,), Type: float32)
# Dataset: o2sjOBiBXSc (Shape: (768,), Type: float32)
# Dataset: oKXV-XQzUrY (Shape: (768,), Type: float32)
# Dataset: oMx6C31dCeo (Shape: (768,), Type: float32)
# Dataset: oZu2JfM2Aq8 (Shape: (768,), Type: float32)
# Dataset: o_3BdeGhzrs (Shape: (768,), Type: float32)
# Dataset: ocqy8r8rDI0 (Shape: (768,), Type: float32)
# Dataset: odvIh7iwK2E (Shape: (768,), Type: float32)
# Dataset: ohz8_IafGwE (Shape: (768,), Type: float32)
# Dataset: okiMnLyCMbA (Shape: (768,), Type: float32)
# Dataset: p2fHtpp_umI (Shape: (768,), Type: float32)
# Dataset: p890hIa1w9k (Shape: (768,), Type: float32)
# Dataset: pDnPZ0Ccdus (Shape: (768,), Type: float32)
# Dataset: pHBKmT6eNGw (Shape: (768,), Type: float32)
# Dataset: pO09fucTEuk (Shape: (768,), Type: float32)
# Dataset: pTptxpcYySI (Shape: (768,), Type: float32)
# Dataset: pU3klLr1CPA (Shape: (768,), Type: float32)
# Dataset: pWfB7jrCgxk (Shape: (768,), Type: float32)
# Dataset: pbzjsBcOuB8 (Shape: (768,), Type: float32)
# Dataset: pcj4boVT4fc (Shape: (768,), Type: float32)
# Dataset: pexcH4Ffi8I (Shape: (768,), Type: float32)
# Dataset: pnTtzyItCQA (Shape: (768,), Type: float32)
# Dataset: pnaWqq2eRcc (Shape: (768,), Type: float32)
# Dataset: pvNA2JkMfSI (Shape: (768,), Type: float32)
# Dataset: pwL0PcIHtxQ (Shape: (768,), Type: float32)
# Dataset: q9Wip3v8h40 (Shape: (768,), Type: float32)
# Dataset: qCpDKjDMo6Y (Shape: (768,), Type: float32)
# Dataset: qDTmyJdVAF0 (Shape: (768,), Type: float32)
# Dataset: qEH9lnYIndY (Shape: (768,), Type: float32)
# Dataset: qLCy66eZrQs (Shape: (768,), Type: float32)
# Dataset: qQgyoHsknIk (Shape: (768,), Type: float32)
# Dataset: qRQu4tZF1GA (Shape: (768,), Type: float32)
# Dataset: qYufeLaIggU (Shape: (768,), Type: float32)
# Dataset: qZubhGcnsHk (Shape: (768,), Type: float32)
# Dataset: qaBlaPsuHQw (Shape: (768,), Type: float32)
# Dataset: qeZ0SIG2eJY (Shape: (768,), Type: float32)
# Dataset: qjFCVTpsIps (Shape: (768,), Type: float32)
# Dataset: qj_NSmG9m5E (Shape: (768,), Type: float32)
# Dataset: qlUmBE6uGu8 (Shape: (768,), Type: float32)
# Dataset: qoXJJin1e7g (Shape: (768,), Type: float32)
# Dataset: qyLJCNyRov0 (Shape: (768,), Type: float32)
# Dataset: r-ddXOrPiZ0 (Shape: (768,), Type: float32)
# Dataset: r1S-yBBZsDI (Shape: (768,), Type: float32)
# Dataset: r2fHzai5ih4 (Shape: (768,), Type: float32)
# Dataset: r38fEGep2yU (Shape: (768,), Type: float32)
# Dataset: r67faKKQyO4 (Shape: (768,), Type: float32)
# Dataset: rBgn0IhMEBk (Shape: (768,), Type: float32)
# Dataset: rEAbZTpV47E (Shape: (768,), Type: float32)
# Dataset: rKh4muRk_s0 (Shape: (768,), Type: float32)
# Dataset: rOoBvxdO0Ac (Shape: (768,), Type: float32)
# Dataset: rRlfzy7Rxdo (Shape: (768,), Type: float32)
# Dataset: rSPj_G2yVz4 (Shape: (768,), Type: float32)
# Dataset: rVFi-yeTe5g (Shape: (768,), Type: float32)
# Dataset: rfeDWXk1jso (Shape: (768,), Type: float32)
# Dataset: rpdnpip1X4A (Shape: (768,), Type: float32)
# Dataset: rsnLwzzkF_Q (Shape: (768,), Type: float32)
# Dataset: rsyw13yrRoo (Shape: (768,), Type: float32)
# Dataset: rt3FEbzjM3o (Shape: (768,), Type: float32)
# Dataset: ry88dGpJKZk (Shape: (768,), Type: float32)
# Dataset: s2Tpk6RnkaA (Shape: (768,), Type: float32)
# Dataset: s5jDTz07buw (Shape: (768,), Type: float32)
# Dataset: s9prJba2vkw (Shape: (768,), Type: float32)
# Dataset: sGuNGXmQZSE (Shape: (768,), Type: float32)
# Dataset: sKrqOTg_FJY (Shape: (768,), Type: float32)
# Dataset: sP9ufyH-Pdg (Shape: (768,), Type: float32)
# Dataset: sSHxFSaOV-o (Shape: (768,), Type: float32)
# Dataset: sSc4Y4Z9lsk (Shape: (768,), Type: float32)
# Dataset: sh0UuxRgqgk (Shape: (768,), Type: float32)
# Dataset: sqZ6ZrVIemM (Shape: (768,), Type: float32)
# Dataset: sqmzvduQ-JY (Shape: (768,), Type: float32)
# Dataset: ssK4Uc8SXnU (Shape: (768,), Type: float32)
# Dataset: svytEWJK6Qk (Shape: (768,), Type: float32)
# Dataset: t-5usV6m4J4 (Shape: (768,), Type: float32)
# Dataset: t0Yf_fvD-lY (Shape: (768,), Type: float32)
# Dataset: tG2qsoC_-hs (Shape: (768,), Type: float32)
# Dataset: tGs4xAZJkps (Shape: (768,), Type: float32)
# Dataset: tGxxl7LOe_4 (Shape: (768,), Type: float32)
# Dataset: tLUrEgC-Dd4 (Shape: (768,), Type: float32)
# Dataset: tNvDa9kTDUw (Shape: (768,), Type: float32)
# Dataset: tOeINWwKvoA (Shape: (768,), Type: float32)
# Dataset: tX74H9IuYdM (Shape: (768,), Type: float32)
# Dataset: t_9GTwEOdkY (Shape: (768,), Type: float32)
# Dataset: ti9jg0JOK2I (Shape: (768,), Type: float32)
# Dataset: tiYXgCsoqaA (Shape: (768,), Type: float32)
# Dataset: trxN4ftuxKQ (Shape: (768,), Type: float32)
# Dataset: ttIN2nLcy6s (Shape: (768,), Type: float32)
# Dataset: u4gz2yNW_Go (Shape: (768,), Type: float32)
# Dataset: u7IXETT9OEQ (Shape: (768,), Type: float32)
# Dataset: uE8yYJmpxeI (Shape: (768,), Type: float32)
# Dataset: uEYm9Zm5zI8 (Shape: (768,), Type: float32)
# Dataset: uIsdG0ydS5o (Shape: (768,), Type: float32)
# Dataset: uW7Pev3qG1k (Shape: (768,), Type: float32)
# Dataset: u_6tnXDfxBo (Shape: (768,), Type: float32)
# Dataset: ujC4W8hJ4mg (Shape: (768,), Type: float32)
# Dataset: urbo6F_qD5k (Shape: (768,), Type: float32)
# Dataset: uvAd-GbYBVw (Shape: (768,), Type: float32)
# Dataset: uvUH_niF-Zo (Shape: (768,), Type: float32)
# Dataset: uvXwt5HNFLU (Shape: (768,), Type: float32)
# Dataset: v8pFeR0jO38 (Shape: (768,), Type: float32)
# Dataset: vBLcmGPbryg (Shape: (768,), Type: float32)
# Dataset: vG6bW7_-CRQ (Shape: (768,), Type: float32)
# Dataset: vJv647j5Ig4 (Shape: (768,), Type: float32)
# Dataset: vKjBFsyYC0g (Shape: (768,), Type: float32)
# Dataset: vO2jvLIyIV4 (Shape: (768,), Type: float32)
# Dataset: vXQlXYcAksI (Shape: (768,), Type: float32)
# Dataset: vZKaVV0ZyFs (Shape: (768,), Type: float32)
# Dataset: v_lHiT6UVCE (Shape: (768,), Type: float32)
# Dataset: vaJ2yQC_ktY (Shape: (768,), Type: float32)
# Dataset: veztNJQyRJg (Shape: (768,), Type: float32)
# Dataset: vhhiJqQBMMY (Shape: (768,), Type: float32)
# Dataset: vn9awsg8BjA (Shape: (768,), Type: float32)
# Dataset: vnh7gxa0z4Q (Shape: (768,), Type: float32)
# Dataset: vqPT1IbJrX8 (Shape: (768,), Type: float32)
# Dataset: vrhgkmAzWvo (Shape: (768,), Type: float32)
# Dataset: vubylfvbMhk (Shape: (768,), Type: float32)
# Dataset: vuvmITfWFuo (Shape: (768,), Type: float32)
# Dataset: vw1dPsf0JgE (Shape: (768,), Type: float32)
# Dataset: vykvU-52g6w (Shape: (768,), Type: float32)
# Dataset: vz2RAznAy9Q (Shape: (768,), Type: float32)
# Dataset: w6YTq-3hmnA (Shape: (768,), Type: float32)
# Dataset: w71pHLUz2i0 (Shape: (768,), Type: float32)
# Dataset: w7ZY9tqDsEc (Shape: (768,), Type: float32)
# Dataset: wAJQ-yWgSJs (Shape: (768,), Type: float32)
# Dataset: wIC34lZi_NU (Shape: (768,), Type: float32)
# Dataset: wMu4IBsX--I (Shape: (768,), Type: float32)
# Dataset: wPmgfWpamb0 (Shape: (768,), Type: float32)
# Dataset: wtMDZyMGKe0 (Shape: (768,), Type: float32)
# Dataset: wyRq2S8BTVM (Shape: (768,), Type: float32)
# Dataset: x0ce_01UW_Q (Shape: (768,), Type: float32)
# Dataset: x883mrwYjDM (Shape: (768,), Type: float32)
# Dataset: x9U9Xi1yQMo (Shape: (768,), Type: float32)
# Dataset: xAmgUnwxCUc (Shape: (768,), Type: float32)
# Dataset: xCQ3ZdnptUM (Shape: (768,), Type: float32)
# Dataset: xGN5cFcaD5A (Shape: (768,), Type: float32)
# Dataset: xHtAfA2ctBs (Shape: (768,), Type: float32)
# Dataset: xSmmiAl9ZWE (Shape: (768,), Type: float32)
# Dataset: xTseWiI_yns (Shape: (768,), Type: float32)
# Dataset: xamDprXBtBg (Shape: (768,), Type: float32)
# Dataset: xeLH_cCCgr0 (Shape: (768,), Type: float32)
# Dataset: xfF-ZL3xvxw (Shape: (768,), Type: float32)
# Dataset: xvZRXcg4iS8 (Shape: (768,), Type: float32)
# Dataset: y87LPJHRfOI (Shape: (768,), Type: float32)
# Dataset: y8Jkls3xgvg (Shape: (768,), Type: float32)
# Dataset: yAmTu-R5MQM (Shape: (768,), Type: float32)
# Dataset: yCIgtidXAnQ (Shape: (768,), Type: float32)
# Dataset: yDoaKW48_hk (Shape: (768,), Type: float32)
# Dataset: yNeQm5aqrHo (Shape: (768,), Type: float32)
# Dataset: yNs0hmNinA0 (Shape: (768,), Type: float32)
# Dataset: yOgdjlPRWMg (Shape: (768,), Type: float32)
# Dataset: yQXi94aNwBU (Shape: (768,), Type: float32)
# Dataset: yWZtEE8C1x4 (Shape: (768,), Type: float32)
# Dataset: ylvCOlF5RLI (Shape: (768,), Type: float32)
# Dataset: yo7C-Sp_-MI (Shape: (768,), Type: float32)
# Dataset: yooamJf-T_8 (Shape: (768,), Type: float32)
# Dataset: ysLBlalu91s (Shape: (768,), Type: float32)
# Dataset: yy6j2LUyh24 (Shape: (768,), Type: float32)
# Dataset: z0BandJg8y4 (Shape: (768,), Type: float32)
# Dataset: z4NqFwQCHQg (Shape: (768,), Type: float32)
# Dataset: zPa3qf25T3s (Shape: (768,), Type: float32)
# Dataset: zS3qOr0zAJg (Shape: (768,), Type: float32)
# Dataset: zVIDGJxo238 (Shape: (768,), Type: float32)
# Dataset: zVeJ5F26uiM (Shape: (768,), Type: float32)
# Dataset: zWzRkf2uwQk (Shape: (768,), Type: float32)
# Dataset: zXR_4li9ZnA (Shape: (768,), Type: float32)
# Dataset: zeKb7O1KtIU (Shape: (768,), Type: float32)
# Dataset: zi-vtjCN9Rw (Shape: (768,), Type: float32)
# Dataset: zm9XOZXVyyU (Shape: (768,), Type: float32)
# Dataset: zpvTZ0G0UiM (Shape: (768,), Type: float32)
